# %%
from mwviews.api import PageviewsClient

# %%
p = PageviewsClient()

# %%
project = 'en'
articles = ['RSA_Factoring_Challenge']
st = '20170101'
end = '20170814'

# %%
resp = p.article_views(project + '.wikipedia', articles, start=st, end=end)

# %%
resp
# Out:
# defaultdict(dict,
#             {datetime.datetime(2017, 1, 1, 0, 0): {'RSA_Factoring_Challenge': 71},
#              datetime.datetime(2017, 1, 2, 0, 0): {'RSA_Factoring_Challenge': 118},
#              datetime.datetime(2017, 1, 3, 0, 0): {'RSA_Factoring_Challenge': 97},
#              datetime.datetime(2017, 1, 4, 0, 0): {'RSA_Factoring_Challenge': 88},
#              datetime.datetime(2017, 1, 5, 0, 0): {'RSA_Factoring_Challenge': 113},
#              datetime.datetime(2017, 1, 6, 0, 0): {'RSA_Factoring_Challenge': 109},
#              datetime.datetime(2017, 1, 7, 0, 0): {'RSA_Factoring_Challenge': 70},
#              datetime.datetime(2017, 1, 8, 0, 0): {'RSA_Factoring_Challenge': 78},
#              datetime.datetime(2017, 1, 9, 0, 0): {'RSA_Factoring_Challenge': 121},
#              datetime.datetime(2017, 1, 10, 0, 0): {'RSA_Factoring_Challenge': 139},
#              datetime.datetime(2017, 1, 11, 0, 0): {'RSA_Factoring_Challenge': 142},
# ...
